# %%
import cv2 
import cvzone

# %%
# !pip install cvzone
# Out:
# Collecting cvzone
#   Downloading cvzone-1.6.1.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: opencv-python in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from cvzone) (4.9.0.80)
# Requirement already satisfied: numpy in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from cvzone) (1.26.1)
# Building wheels for collected packages: cvzone
#   Building wheel for cvzone (setup.py): started
#   Building wheel for cvzone (setup.py): finished with status 'done'
#   Created wheel for cvzone: filename=cvzone-1.6.1-py3-none-any.whl size=26309 sha256=ff7ec97fce814f4f21c12be277c7b48f4b62b21925896936a19232abf6d6e456
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\5d\21\e8\3147ae88d44e27f06e0175d337a7673c70fb957202cbbe2034
# Successfully built cvzone
# Installing collected packages: cvzone
# Successfully installed cvzone-1.6.1

# %%
cap = cv2.VideoCapture(0)
cap.set(3,640)
cap.set(4,480)
while True:  
    imgBG = cv2.imread("C:/Users/admin/Documents/Studies/Projects/ML/RPS_Game/Resources/BG.png")
    success, img = cap.read()
    
    imgScaled = cv2.resize(img,(0,0),None,0.875)
    
    cv2.imshow("BG",imgBG)
    cv2.imshow("Image",img)

    cv2.waitKey(1)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 8
#       5 imgBG = cv2.imread("C:/Users/admin/Documents/Studies/Projects/ML/RPS_Game/Resources/BG.png")
#       6 success, img = cap.read()
# ----> 8 imgScaled = cv2.resize(img,(0,0),None,0.875)
#      10 cv2.imshow("BG",imgBG)
#      11 cv2.imshow("Image",img)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4155: error: (-215:Assertion failed) inv_scale_y > 0 in function 'cv::resize'

# %%
cap.release()

# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 cv2.destroyAllWindows()
#
# error: OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1266: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvDestroyAllWindows'

# %%
import random
import cv2
import cvzone
from cvzone.HandTrackingModule import HandDetector
import time
 
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)
 
detector = HandDetector(maxHands=1)
 
timer = 0
stateResult = False
startGame = False
scores = [0, 0]  # [AI, Player]
 
while True:
    imgBG = cv2.imread("Resources/BG.png")
    success, img = cap.read()
 
    imgScaled = cv2.resize(img, (0, 0), None, 0.875, 0.875)
    imgScaled = imgScaled[:, 80:480]
 
    # Find Hands
    hands, img = detector.findHands(imgScaled)  # with draw
 
    if startGame:
 
        if stateResult is False:
            timer = time.time() - initialTime
            cv2.putText(imgBG, str(int(timer)), (605, 435), cv2.FONT_HERSHEY_PLAIN, 6, (255, 0, 255), 4)
 
            if timer > 3:
                stateResult = True
                timer = 0
 
                if hands:
                    playerMove = None
                    hand = hands[0]
                    fingers = detector.fingersUp(hand)
                    if fingers == [0, 0, 0, 0, 0]:
                        playerMove = 1
                    if fingers == [1, 1, 1, 1, 1]:
                        playerMove = 2
                    if fingers == [0, 1, 1, 0, 0]:
                        playerMove = 3
 
                    randomNumber = random.randint(1, 3)
                    imgAI = cv2.imread(f'Resources/{randomNumber}.png', cv2.IMREAD_UNCHANGED)
                    imgBG = cvzone.overlayPNG(imgBG, imgAI, (149, 310))
 
                    # Player Wins
                    if (playerMove == 1 and randomNumber == 3) or \
                            (playerMove == 2 and randomNumber == 1) or \
                            (playerMove == 3 and randomNumber == 2):
                        scores[1] += 1
 
                    # AI Wins
                    if (playerMove == 3 and randomNumber == 1) or \
                            (playerMove == 1 and randomNumber == 2) or \
                            (playerMove == 2 and randomNumber == 3):
                        scores[0] += 1
 
    imgBG[234:654, 795:1195] = imgScaled
 
    if stateResult:
        imgBG = cvzone.overlayPNG(imgBG, imgAI, (149, 310))
 
    cv2.putText(imgBG, str(scores[0]), (410, 215), cv2.FONT_HERSHEY_PLAIN, 4, (255, 255, 255), 6)
    cv2.putText(imgBG, str(scores[1]), (1112, 215), cv2.FONT_HERSHEY_PLAIN, 4, (255, 255, 255), 6)
 
    # cv2.imshow("Image", img)
    cv2.imshow("BG", imgBG)
    # cv2.imshow("Scaled", imgScaled)
 
    key = cv2.waitKey(1)
    if key == ord('s'):
        startGame = True
        initialTime = time.time()
        stateResult = False
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 4
#       2 import cv2
#       3 import cvzone
# ----> 4 from cvzone.HandTrackingModule import HandDetector
#       5 import time
#       7 cap = cv2.VideoCapture(0)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\cvzone\HandTrackingModule.py:10
#       7 import math
#       9 import cv2
# ---> 10 import mediapipe as mp
#      13 class HandDetector:
#      14     """
#      15     Finds Hands using the mediapipe library. Exports the landmarks
#      16     in pixel format. Adds extra functionalities like finding how
#      17     many fingers are up or the distance between two fingers. Also
#      18     provides bounding box info of the hand found.
#      19     """
#
# ModuleNotFoundError: No module named 'mediapipe'

# %%
# !pip install mediapipe
# Out:
# Collecting mediapipe
#   Using cached mediapipe-0.10.14-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# Requirement already satisfied: absl-py in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (24.3.25)
# Collecting jax (from mediapipe)
#   Using cached jax-0.4.28-py3-none-any.whl.metadata (23 kB)
# Collecting jaxlib (from mediapipe)
#   Using cached jaxlib-0.4.28-cp312-cp312-win_amd64.whl.metadata (1.8 kB)
# Requirement already satisfied: matplotlib in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (3.8.2)
# Requirement already satisfied: numpy in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (1.26.1)
# Collecting opencv-contrib-python (from mediapipe)
#   Downloading opencv_contrib_python-4.10.0.82-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (4.25.3)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Using cached sounddevice-0.4.7-py3-none-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: CFFI>=1.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (0.3.2)
# Requirement already satisfied: opt-einsum in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (1.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from cycler>=0.10->matplotlib->mediapipe) (1.16.0)
# Using cached mediapipe-0.10.14-cp312-cp312-win_amd64.whl (50.8 MB)
# Using cached sounddevice-0.4.7-py3-none-win_amd64.whl (200 kB)
# Using cached jax-0.4.28-py3-none-any.whl (1.9 MB)
# Using cached jaxlib-0.4.28-cp312-cp312-win_amd64.whl (51.5 MB)
# Downloading opencv_contrib_python-4.10.0.82-cp37-abi3-win_amd64.whl (45.5 MB)
#    ---------------------------------------- 0.0/45.5 MB ? eta -:--:--
#    ---------------------------------------- 0.2/45.5 MB 4.5 MB/s eta 0:00:11
#     --------------------------------------- 0.6/45.5 MB 8.1 MB/s eta 0:00:06
#     --------------------------------------- 1.1/45.5 MB 8.4 MB/s eta 0:00:06
#    - -------------------------------------- 1.6/45.5 MB 9.0 MB/s eta 0:00:05
#    - -------------------------------------- 2.1/45.5 MB 9.6 MB/s eta 0:00:05
#    -- ------------------------------------- 2.7/45.5 MB 10.0 MB/s eta 0:00:05
#    -- ------------------------------------- 3.2/45.5 MB 10.2 MB/s eta 0:00:05
#    --- ------------------------------------ 3.7/45.5 MB 10.4 MB/s eta 0:00:05
#    --- ------------------------------------ 4.1/45.5 MB 9.9 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.6/45.5 MB 10.0 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.8/45.5 MB 9.6 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.8/45.5 MB 9.6 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.9/45.5 MB 8.2 MB/s eta 0:00:05
#    ---- ----------------------------------- 5.2/45.5 MB 8.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 5.7/45.5 MB 8.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 6.1/45.5 MB 8.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 6.7/45.5 MB 8.6 MB/s eta 0:00:05
#    ------ --------------------------------- 7.1/45.5 MB 8.6 MB/s eta 0:00:05
#    ------ --------------------------------- 7.6/45.5 MB 8.8 MB/s eta 0:00:05
#    ------- -------------------------------- 8.0/45.5 MB 8.7 MB/s eta 0:00:05
#    ------- -------------------------------- 8.5/45.5 MB 8.7 MB/s eta 0:00:05
#    ------- -------------------------------- 8.9/45.5 MB 8.7 MB/s eta 0:00:05
#    -------- ------------------------------- 9.4/45.5 MB 8.8 MB/s eta 0:00:05
#    -------- ------------------------------- 9.9/45.5 MB 8.9 MB/s eta 0:00:04
#    -------- ------------------------------- 10.2/45.5 MB 8.8 MB/s eta 0:00:05
#    --------- ------------------------------ 10.7/45.5 MB 9.1 MB/s eta 0:00:04
#    --------- ------------------------------ 10.9/45.5 MB 9.0 MB/s eta 0:00:04
#    --------- ------------------------------ 11.2/45.5 MB 8.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 11.9/45.5 MB 8.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 12.2/45.5 MB 8.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 12.7/45.5 MB 8.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 13.1/45.5 MB 8.6 MB/s eta 0:00:04
#    ----------- ---------------------------- 13.6/45.5 MB 8.5 MB/s eta 0:00:04
#    ------------ --------------------------- 14.0/45.5 MB 8.4 MB/s eta 0:00:04
#    ------------ --------------------------- 14.5/45.5 MB 8.6 MB/s eta 0:00:04
#    ------------- -------------------------- 14.9/45.5 MB 8.5 MB/s eta 0:00:04
#    ------------- -------------------------- 15.3/45.5 MB 9.4 MB/s eta 0:00:04
#    ------------- -------------------------- 15.7/45.5 MB 9.2 MB/s eta 0:00:04
#    -------------- ------------------------- 16.1/45.5 MB 9.4 MB/s eta 0:00:04
#    -------------- ------------------------- 16.3/45.5 MB 9.2 MB/s eta 0:00:04
#    -------------- ------------------------- 16.7/45.5 MB 9.2 MB/s eta 0:00:04
#    --------------- ------------------------ 17.2/45.5 MB 9.1 MB/s eta 0:00:04
#    --------------- ------------------------ 17.6/45.5 MB 9.0 MB/s eta 0:00:04
#    --------------- ------------------------ 17.9/45.5 MB 9.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 18.3/45.5 MB 9.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 18.8/45.5 MB 9.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 19.3/45.5 MB 9.1 MB/s eta 0:00:03
#    ----------------- ---------------------- 19.8/45.5 MB 9.1 MB/s eta 0:00:03
#    ----------------- ---------------------- 20.3/45.5 MB 9.0 MB/s eta 0:00:03
#    ------------------ --------------------- 20.8/45.5 MB 9.1 MB/s eta 0:00:03
#    ------------------ --------------------- 21.2/45.5 MB 9.2 MB/s eta 0:00:03
#    ------------------ --------------------- 21.5/45.5 MB 9.2 MB/s eta 0:00:03
#    ------------------- -------------------- 22.0/45.5 MB 9.1 MB/s eta 0:00:03
#    ------------------- -------------------- 22.4/45.5 MB 9.1 MB/s eta 0:00:03
#    -------------------- ------------------- 22.8/45.5 MB 9.1 MB/s eta 0:00:03
#    -------------------- ------------------- 23.2/45.5 MB 9.1 MB/s eta 0:00:03
#    -------------------- ------------------- 23.6/45.5 MB 9.0 MB/s eta 0:00:03
#    --------------------- ------------------ 24.0/45.5 MB 9.0 MB/s eta 0:00:03
#    --------------------- ------------------ 24.4/45.5 MB 9.0 MB/s eta 0:00:03
#    --------------------- ------------------ 24.8/45.5 MB 9.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 25.3/45.5 MB 8.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 25.6/45.5 MB 9.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 25.9/45.5 MB 8.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 26.2/45.5 MB 8.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 26.6/45.5 MB 8.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 26.9/45.5 MB 8.7 MB/s eta 0:00:03
#    ------------------------ --------------- 27.3/45.5 MB 8.8 MB/s eta 0:00:03
#    ------------------------ --------------- 27.7/45.5 MB 8.7 MB/s eta 0:00:03
#    ------------------------ --------------- 28.1/45.5 MB 9.0 MB/s eta 0:00:02
#    ------------------------- -------------- 28.5/45.5 MB 8.8 MB/s eta 0:00:02
#    ------------------------- -------------- 29.1/45.5 MB 8.8 MB/s eta 0:00:02
#    ------------------------- -------------- 29.5/45.5 MB 8.8 MB/s eta 0:00:02
#    -------------------------- ------------- 29.8/45.5 MB 8.7 MB/s eta 0:00:02
#    -------------------------- ------------- 30.2/45.5 MB 8.7 MB/s eta 0:00:02
#    -------------------------- ------------- 30.7/45.5 MB 8.7 MB/s eta 0:00:02
#    --------------------------- ------------ 31.0/45.5 MB 8.6 MB/s eta 0:00:02
#    --------------------------- ------------ 31.4/45.5 MB 8.6 MB/s eta 0:00:02
#    --------------------------- ------------ 31.9/45.5 MB 8.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 32.3/45.5 MB 8.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 32.7/45.5 MB 8.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.1/45.5 MB 8.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.7/45.5 MB 8.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.7/45.5 MB 8.6 MB/s eta 0:00:02
#    ------------------------------ --------- 34.2/45.5 MB 8.6 MB/s eta 0:00:02
#    ------------------------------ --------- 34.7/45.5 MB 8.5 MB/s eta 0:00:02
#    ------------------------------ --------- 35.1/45.5 MB 8.6 MB/s eta 0:00:02
#    ------------------------------- -------- 35.6/45.5 MB 8.6 MB/s eta 0:00:02
#    ------------------------------- -------- 35.9/45.5 MB 8.7 MB/s eta 0:00:02
#    ------------------------------- -------- 36.2/45.5 MB 8.7 MB/s eta 0:00:02
#    -------------------------------- ------- 36.7/45.5 MB 8.7 MB/s eta 0:00:02
#    -------------------------------- ------- 37.2/45.5 MB 8.8 MB/s eta 0:00:01
#    --------------------------------- ------ 37.6/45.5 MB 8.8 MB/s eta 0:00:01
#    --------------------------------- ------ 38.0/45.5 MB 8.8 MB/s eta 0:00:01
#    --------------------------------- ------ 38.5/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.9/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 39.2/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 39.5/45.5 MB 8.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 39.9/45.5 MB 8.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.3/45.5 MB 8.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.7/45.5 MB 8.6 MB/s eta 0:00:01
#    ------------------------------------ --- 41.2/45.5 MB 8.7 MB/s eta 0:00:01
#    ------------------------------------ --- 41.6/45.5 MB 8.6 MB/s eta 0:00:01
#    ------------------------------------ --- 42.0/45.5 MB 8.6 MB/s eta 0:00:01
#    ------------------------------------- -- 42.4/45.5 MB 8.7 MB/s eta 0:00:01
#    ------------------------------------- -- 42.8/45.5 MB 8.7 MB/s eta 0:00:01
#    ------------------------------------- -- 43.2/45.5 MB 8.7 MB/s eta 0:00:01
#    -------------------------------------- - 43.7/45.5 MB 8.7 MB/s eta 0:00:01
#    -------------------------------------- - 44.1/45.5 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------  44.5/45.5 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------------  44.9/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  45.3/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  45.5/45.5 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 45.5/45.5 MB 5.6 MB/s eta 0:00:00
# Installing collected packages: opencv-contrib-python, sounddevice, jaxlib, jax, mediapipe
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\admin\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.
